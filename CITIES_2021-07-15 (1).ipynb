# %% [markdown]
# ## Overview
#
# This notebook will show you how to create and query a table or DataFrame that you uploaded to DBFS. [DBFS](https://docs.databricks.com/user-guide/dbfs-databricks-file-system.html) is a Databricks File System that allows you to store data for querying inside of Databricks. This notebook assumes that you have a file already inside of DBFS that you would like to read from.
#
# This notebook is written in **Python** so the default cell type is Python. However, you can use different languages by using the `%LANGUAGE` syntax. Python, Scala, SQL, and R are all supported.

# %%
import pandas as pd
import numpy as np
import os
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#data = pd.read_csv("FileStore/tables/2020_Full_Cities_Dataset_1_-1.csv")

# %%
# File location and type
file_location = "/FileStore/tables/2020_Full_Cities_Dataset_1_-1.csv"
file_type = "csv"

# CSV options
infer_schema = "true"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
df = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [(&#39;Questionnaire&#39;, &#39;string&#39;),
#  (&#39;Year Reported to CDP&#39;, &#39;int&#39;),
#  (&#39;Account Number&#39;, &#39;int&#39;),
#  (&#39;Organization&#39;, &#39;string&#39;),
#  (&#39;Country&#39;, &#39;string&#39;),
#  (&#39;CDP Region&#39;, &#39;string&#39;),
#  (&#39;Parent Section&#39;, &#39;string&#39;),
#  (&#39;Section&#39;, &#39;string&#39;),
#  (&#39;Question Number&#39;, &#39;string&#39;),
#  (&#39;Question Name&#39;, &#39;string&#39;),
#  (&#39;Column Number&#39;, &#39;string&#39;),
#  (&#39;Column Name&#39;, &#39;string&#39;),
#  (&#39;Row Number&#39;, &#39;string&#39;),
#  (&#39;Row Name&#39;, &#39;string&#39;),
#  (&#39;Response Answer&#39;, &#39;string&#39;),
#  (&#39;Comments&#39;, &#39;string&#39;),
#  (&#39;File Name&#39;, &#39;string&#39;),
#  (&#39;Last update&#39;, &#39;string&#39;)]</div>

# %%
data = df.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questionnaire</th>
#       <th>Year Reported to CDP</th>
#       <th>Account Number</th>
#       <th>Organization</th>
#       <th>Country</th>
#       <th>CDP Region</th>
#       <th>Parent Section</th>
#       <th>Section</th>
#       <th>Question Number</th>
#       <th>Question Name</th>
#       <th>Column Number</th>
#       <th>Column Name</th>
#       <th>Row Number</th>
#       <th>Row Name</th>
#       <th>Response Answer</th>
#       <th>Comments</th>
#       <th>File Name</th>
#       <th>Last update</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>68296</td>
#       <td>Hobsons Bay City Council</td>
#       <td>Australia</td>
#       <td>Southeast Asia and Oceania</td>
#       <td>None</td>
#       <td>Transport</td>
#       <td>10.6</td>
#       <td>How many buses has your city procured in the l...</td>
#       <td>2</td>
#       <td>Comment</td>
#       <td>5</td>
#       <td>Plug-in hybrid</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>8242</td>
#       <td>City of Helsinki</td>
#       <td>Finland</td>
#       <td>Europe</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>1</td>
#       <td>Direct emissions (metric tonnes CO2e)</td>
#       <td>6</td>
#       <td>Stationary energy &gt; Fugitive emissions</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>73301</td>
#       <td>City of Gretna, LA</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>Opportunities</td>
#       <td>Finance and Economic Opportunities</td>
#       <td>6.5</td>
#       <td>List any mitigation, adaptation, water related...</td>
#       <td>5</td>
#       <td>Financing model identified</td>
#       <td>4</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>54488</td>
#       <td>Trondheim Municipality</td>
#       <td>Norway</td>
#       <td>Europe</td>
#       <td>None</td>
#       <td>Transport</td>
#       <td>10.6</td>
#       <td>How many buses has your city procured in the l...</td>
#       <td>1</td>
#       <td>Number of buses</td>
#       <td>6</td>
#       <td>Hydrogen</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>54696</td>
#       <td>XIV Ayuntamiento de La Paz</td>
#       <td>Mexico</td>
#       <td>Latin America</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>6</td>
#       <td>If you have no emissions occurring outside the...</td>
#       <td>27</td>
#       <td>Generation of grid-supplied energy &gt; CHP gener...</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data.tail()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questionnaire</th>
#       <th>Year Reported to CDP</th>
#       <th>Account Number</th>
#       <th>Organization</th>
#       <th>Country</th>
#       <th>CDP Region</th>
#       <th>Parent Section</th>
#       <th>Section</th>
#       <th>Question Number</th>
#       <th>Question Name</th>
#       <th>Column Number</th>
#       <th>Column Name</th>
#       <th>Row Number</th>
#       <th>Row Name</th>
#       <th>Response Answer</th>
#       <th>Comments</th>
#       <th>File Name</th>
#       <th>Last update</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>869308</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>59678</td>
#       <td>City of Evanston, IL</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>City-wide Emissions</td>
#       <td>GCoM Emission Factor and Activity Data</td>
#       <td>4.15</td>
#       <td>Please provide a summary of emissions factors ...</td>
#       <td>7</td>
#       <td>Emission factor unit (numerator)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869309</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>31108</td>
#       <td>City of Houston</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>Opportunities</td>
#       <td>Finance and Economic Opportunities</td>
#       <td>6.5</td>
#       <td>List any mitigation, adaptation, water related...</td>
#       <td>5</td>
#       <td>Financing model identified</td>
#       <td>18</td>
#       <td>None</td>
#       <td>No</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869310</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>36477</td>
#       <td>Comune di Lucca</td>
#       <td>Italy</td>
#       <td>Europe</td>
#       <td>Climate Hazards and Vulnerability</td>
#       <td>Climate Hazards</td>
#       <td>2.3</td>
#       <td>Is your city facing risks to public health or ...</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869311</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>44185</td>
#       <td>Suwon City</td>
#       <td>Republic of Korea</td>
#       <td>East Asia</td>
#       <td>Emissions Reduction</td>
#       <td>Mitigation Actions</td>
#       <td>5.4</td>
#       <td>Describe the anticipated outcomes of the most ...</td>
#       <td>5</td>
#       <td>Estimated emissions reduction (metric tonnes C...</td>
#       <td>1</td>
#       <td>None</td>
#       <td>12599</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869312</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>31182</td>
#       <td>City of San Francisco</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>7</td>
#       <td>Please explain any excluded sources, identify ...</td>
#       <td>14</td>
#       <td>Waste &gt; Solid waste disposal</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#how many missing values in each column, here sum() function is actually sum(axis=o), so this means a False gets to be assigned 0 value, while True, is assigned a '1' value, so that the addition happens across the rows, which means down for each and every column

data.isnull().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: Questionnaire                0
# Year Reported to CDP         0
# Account Number               0
# Organization                 0
# Country                      0
# CDP Region                   0
# Parent Section          205345
# Section                      0
# Question Number              0
# Question Name                0
# Column Number                0
# Column Name              28153
# Row Number                   0
# Row Name                463915
# Response Answer         164057
# Comments                846539
# File Name               866093
# Last update               1686
# dtype: int64</div>

# %%
data.rename(columns={"Parent Section" : "Parent_Section", "Response Answer" : "Response_Answer"})
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questionnaire</th>
#       <th>Year Reported to CDP</th>
#       <th>Account Number</th>
#       <th>Organization</th>
#       <th>Country</th>
#       <th>CDP Region</th>
#       <th>Parent_Section</th>
#       <th>Section</th>
#       <th>Question Number</th>
#       <th>Question Name</th>
#       <th>Column Number</th>
#       <th>Column Name</th>
#       <th>Row Number</th>
#       <th>Row Name</th>
#       <th>Response_Answer</th>
#       <th>Comments</th>
#       <th>File Name</th>
#       <th>Last update</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>68296</td>
#       <td>Hobsons Bay City Council</td>
#       <td>Australia</td>
#       <td>Southeast Asia and Oceania</td>
#       <td>None</td>
#       <td>Transport</td>
#       <td>10.6</td>
#       <td>How many buses has your city procured in the l...</td>
#       <td>2</td>
#       <td>Comment</td>
#       <td>5</td>
#       <td>Plug-in hybrid</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>8242</td>
#       <td>City of Helsinki</td>
#       <td>Finland</td>
#       <td>Europe</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>1</td>
#       <td>Direct emissions (metric tonnes CO2e)</td>
#       <td>6</td>
#       <td>Stationary energy &gt; Fugitive emissions</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>73301</td>
#       <td>City of Gretna, LA</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>Opportunities</td>
#       <td>Finance and Economic Opportunities</td>
#       <td>6.5</td>
#       <td>List any mitigation, adaptation, water related...</td>
#       <td>5</td>
#       <td>Financing model identified</td>
#       <td>4</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>54488</td>
#       <td>Trondheim Municipality</td>
#       <td>Norway</td>
#       <td>Europe</td>
#       <td>None</td>
#       <td>Transport</td>
#       <td>10.6</td>
#       <td>How many buses has your city procured in the l...</td>
#       <td>1</td>
#       <td>Number of buses</td>
#       <td>6</td>
#       <td>Hydrogen</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>54696</td>
#       <td>XIV Ayuntamiento de La Paz</td>
#       <td>Mexico</td>
#       <td>Latin America</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>6</td>
#       <td>If you have no emissions occurring outside the...</td>
#       <td>27</td>
#       <td>Generation of grid-supplied energy &gt; CHP gener...</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>869308</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>59678</td>
#       <td>City of Evanston, IL</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>City-wide Emissions</td>
#       <td>GCoM Emission Factor and Activity Data</td>
#       <td>4.15</td>
#       <td>Please provide a summary of emissions factors ...</td>
#       <td>7</td>
#       <td>Emission factor unit (numerator)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869309</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>31108</td>
#       <td>City of Houston</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>Opportunities</td>
#       <td>Finance and Economic Opportunities</td>
#       <td>6.5</td>
#       <td>List any mitigation, adaptation, water related...</td>
#       <td>5</td>
#       <td>Financing model identified</td>
#       <td>18</td>
#       <td>None</td>
#       <td>No</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869310</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>36477</td>
#       <td>Comune di Lucca</td>
#       <td>Italy</td>
#       <td>Europe</td>
#       <td>Climate Hazards and Vulnerability</td>
#       <td>Climate Hazards</td>
#       <td>2.3</td>
#       <td>Is your city facing risks to public health or ...</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869311</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>44185</td>
#       <td>Suwon City</td>
#       <td>Republic of Korea</td>
#       <td>East Asia</td>
#       <td>Emissions Reduction</td>
#       <td>Mitigation Actions</td>
#       <td>5.4</td>
#       <td>Describe the anticipated outcomes of the most ...</td>
#       <td>5</td>
#       <td>Estimated emissions reduction (metric tonnes C...</td>
#       <td>1</td>
#       <td>None</td>
#       <td>12599</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869312</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>31182</td>
#       <td>City of San Francisco</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>7</td>
#       <td>Please explain any excluded sources, identify ...</td>
#       <td>14</td>
#       <td>Waste &gt; Solid waste disposal</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#   </tbody>
# </table>
# <p>869313 rows × 18 columns</p>
# </div>

# %%
# if to drop all the rows that contain at least one missing value, then:
data.dropna(how = 'any').shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: (46, 18)</div>

# %%
#bring out only those data where the Comments column is null
data[data.Comments.isnull()]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[92]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questionnaire</th>
#       <th>Year Reported to CDP</th>
#       <th>Account Number</th>
#       <th>Organization</th>
#       <th>Country</th>
#       <th>CDP Region</th>
#       <th>Parent Section</th>
#       <th>Section</th>
#       <th>Question Number</th>
#       <th>Question Name</th>
#       <th>Column Number</th>
#       <th>Column Name</th>
#       <th>Row Number</th>
#       <th>Row Name</th>
#       <th>Response Answer</th>
#       <th>Comments</th>
#       <th>File Name</th>
#       <th>Last update</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>68296</td>
#       <td>Hobsons Bay City Council</td>
#       <td>Australia</td>
#       <td>Southeast Asia and Oceania</td>
#       <td>None</td>
#       <td>Transport</td>
#       <td>10.6</td>
#       <td>How many buses has your city procured in the l...</td>
#       <td>2</td>
#       <td>Comment</td>
#       <td>5</td>
#       <td>Plug-in hybrid</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>8242</td>
#       <td>City of Helsinki</td>
#       <td>Finland</td>
#       <td>Europe</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>1</td>
#       <td>Direct emissions (metric tonnes CO2e)</td>
#       <td>6</td>
#       <td>Stationary energy &gt; Fugitive emissions</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>73301</td>
#       <td>City of Gretna, LA</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>Opportunities</td>
#       <td>Finance and Economic Opportunities</td>
#       <td>6.5</td>
#       <td>List any mitigation, adaptation, water related...</td>
#       <td>5</td>
#       <td>Financing model identified</td>
#       <td>4</td>
#       <td>To be explained</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>54488</td>
#       <td>Trondheim Municipality</td>
#       <td>Norway</td>
#       <td>Europe</td>
#       <td>None</td>
#       <td>Transport</td>
#       <td>10.6</td>
#       <td>How many buses has your city procured in the l...</td>
#       <td>1</td>
#       <td>Number of buses</td>
#       <td>6</td>
#       <td>Hydrogen</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>54696</td>
#       <td>XIV Ayuntamiento de La Paz</td>
#       <td>Mexico</td>
#       <td>Latin America</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>6</td>
#       <td>If you have no emissions occurring outside the...</td>
#       <td>27</td>
#       <td>Generation of grid-supplied energy &gt; CHP gener...</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>869308</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>59678</td>
#       <td>City of Evanston, IL</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>City-wide Emissions</td>
#       <td>GCoM Emission Factor and Activity Data</td>
#       <td>4.15</td>
#       <td>Please provide a summary of emissions factors ...</td>
#       <td>7</td>
#       <td>Emission factor unit (numerator)</td>
#       <td>0</td>
#       <td>To be explained</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869309</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>31108</td>
#       <td>City of Houston</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>Opportunities</td>
#       <td>Finance and Economic Opportunities</td>
#       <td>6.5</td>
#       <td>List any mitigation, adaptation, water related...</td>
#       <td>5</td>
#       <td>Financing model identified</td>
#       <td>18</td>
#       <td>To be explained</td>
#       <td>No</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869310</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>36477</td>
#       <td>Comune di Lucca</td>
#       <td>Italy</td>
#       <td>Europe</td>
#       <td>Climate Hazards and Vulnerability</td>
#       <td>Climate Hazards</td>
#       <td>2.3</td>
#       <td>Is your city facing risks to public health or ...</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#       <td>To be explained</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869311</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>44185</td>
#       <td>Suwon City</td>
#       <td>Republic of Korea</td>
#       <td>East Asia</td>
#       <td>Emissions Reduction</td>
#       <td>Mitigation Actions</td>
#       <td>5.4</td>
#       <td>Describe the anticipated outcomes of the most ...</td>
#       <td>5</td>
#       <td>Estimated emissions reduction (metric tonnes C...</td>
#       <td>1</td>
#       <td>To be explained</td>
#       <td>12599</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>869312</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>31182</td>
#       <td>City of San Francisco</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>7</td>
#       <td>Please explain any excluded sources, identify ...</td>
#       <td>14</td>
#       <td>Waste &gt; Solid waste disposal</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#   </tbody>
# </table>
# <p>846539 rows × 18 columns</p>
# </div>

# %%
#£how many rows, how many columns:
data.shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[93]: (869313, 18)</div>

# %%
data.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[94]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questionnaire</th>
#       <th>Year Reported to CDP</th>
#       <th>Account Number</th>
#       <th>Organization</th>
#       <th>Country</th>
#       <th>CDP Region</th>
#       <th>Parent Section</th>
#       <th>Section</th>
#       <th>Question Number</th>
#       <th>Question Name</th>
#       <th>Column Number</th>
#       <th>Column Name</th>
#       <th>Row Number</th>
#       <th>Row Name</th>
#       <th>Response Answer</th>
#       <th>Comments</th>
#       <th>File Name</th>
#       <th>Last update</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>68296</td>
#       <td>Hobsons Bay City Council</td>
#       <td>Australia</td>
#       <td>Southeast Asia and Oceania</td>
#       <td>None</td>
#       <td>Transport</td>
#       <td>10.6</td>
#       <td>How many buses has your city procured in the l...</td>
#       <td>2</td>
#       <td>Comment</td>
#       <td>5</td>
#       <td>Plug-in hybrid</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>8242</td>
#       <td>City of Helsinki</td>
#       <td>Finland</td>
#       <td>Europe</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>1</td>
#       <td>Direct emissions (metric tonnes CO2e)</td>
#       <td>6</td>
#       <td>Stationary energy &gt; Fugitive emissions</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>73301</td>
#       <td>City of Gretna, LA</td>
#       <td>United States of America</td>
#       <td>North America</td>
#       <td>Opportunities</td>
#       <td>Finance and Economic Opportunities</td>
#       <td>6.5</td>
#       <td>List any mitigation, adaptation, water related...</td>
#       <td>5</td>
#       <td>Financing model identified</td>
#       <td>4</td>
#       <td>To be explained</td>
#       <td>None</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>54488</td>
#       <td>Trondheim Municipality</td>
#       <td>Norway</td>
#       <td>Europe</td>
#       <td>None</td>
#       <td>Transport</td>
#       <td>10.6</td>
#       <td>How many buses has your city procured in the l...</td>
#       <td>1</td>
#       <td>Number of buses</td>
#       <td>6</td>
#       <td>Hydrogen</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Cities 2020</td>
#       <td>2020</td>
#       <td>54696</td>
#       <td>XIV Ayuntamiento de La Paz</td>
#       <td>Mexico</td>
#       <td>Latin America</td>
#       <td>City-wide Emissions</td>
#       <td>City-wide GHG Emissions Data</td>
#       <td>4.6a</td>
#       <td>The Global Covenant of Mayors requires committ...</td>
#       <td>6</td>
#       <td>If you have no emissions occurring outside the...</td>
#       <td>27</td>
#       <td>Generation of grid-supplied energy &gt; CHP gener...</td>
#       <td>Question not applicable</td>
#       <td>None</td>
#       <td>None</td>
#       <td>09/07/2020 09:45:36 AM</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
data[data.Organization.isnull()]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[95]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Questionnaire</th>
#       <th>Year Reported to CDP</th>
#       <th>Account Number</th>
#       <th>Organization</th>
#       <th>Country</th>
#       <th>CDP Region</th>
#       <th>Parent Section</th>
#       <th>Section</th>
#       <th>Question Number</th>
#       <th>Question Name</th>
#       <th>Column Number</th>
#       <th>Column Name</th>
#       <th>Row Number</th>
#       <th>Row Name</th>
#       <th>Response Answer</th>
#       <th>Comments</th>
#       <th>File Name</th>
#       <th>Last update</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
#drop rows if all the values are missing
data.dropna(how='all').shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: (869313, 18)</div>

# %%
#drop values if any values are missing in a subset of the dataframe or, the few columns:
data.dropna(subset = ['Parent Section', 'CDP Region' ], how = "any").shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[97]: (663968, 18)</div>

# %%
#drop those rows, for which in the two columns below, the rows have missing values in the same time, what my dframe looks like?
data.dropna(subset = ['Parent Section', 'CDP Region' ], how = "all").shape
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[99]: (869313, 18)</div>

# %%
#How many times each of the values below has occured in the records:
data['Section'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[100]: City-wide GHG Emissions Data                      175056
# Transport                                         104767
# Climate Hazards                                    76633
# Mitigation Actions                                 72043
# Mitigation Target setting                          54754
# Adaptation Actions                                 53957
# Energy                                             32016
# GCoM Emission Factor and Activity Data             29793
# Finance and Economic Opportunities                 26614
# Food                                               23206
# Buildings                                          22120
# Local Government Operations GHG Emissions Data     19643
# Governance                                         18354
# Waste                                              17546
# Adaptation Planning                                16497
# Climate Risk and Vulnerability Assessment          15829
# Adaptation Goals                                   14434
# Mitigation Planning                                13603
# Water Supply Management                            10884
# Water Supply                                       10642
# City-wide external verification                    10188
# Climate Action Planning                             7929
# Historical emissions inventories                    7906
# Collaboration                                       6179
# Re-stating previous emissions inventories           5990
# Opportunities                                       5720
# City Details                                        5094
# Local Government Emissions Verification             3396
# Submit your response                                2294
# Adaptation Planning Process                         2264
# Urban Planning                                      1698
# Introduction                                        1698
# Data Management                                      566
# Name: Section, dtype: int64</div>

# %%
data['Row Name'].value_counts(dropna = False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[101]: To be explained          463915
# Please complete           26044
# Please explain            17546
# City-wide emissions        7924
# Electricity source         6792
#                           ...
# Industrial                  566
# Institutional               566
# Composting                  566
# Re-use                      566
# Ferries / River boats       566
# Name: Row Name, Length: 177, dtype: int64</div>

# %%
#say i 'd like to replace some of the values, like missing values with a 'to be explained' value:

data['Row Name'].fillna(value= 'To be explained', inplace =True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
data['Row Name'].value_counts()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[83]: To be explained          463915
# Please complete           26044
# Please explain            17546
# City-wide emissions        7924
# Electricity source         6792
#                           ...
# Industrial                  566
# Institutional               566
# Composting                  566
# Re-use                      566
# Ferries / River boats       566
# Name: Row Name, Length: 177, dtype: int64</div>

# %%
data.ndim
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: 2</div>

# %%
# Create a view or table

temp_2020_cities = "2020_Full_Cities_Dataset_1_-1_csv"

df.createOrReplaceTempView(temp_2020_cities)

# %% [markdown]
# ## TBC  Not yet finished with EDA

# %%
# %sql

/* Query the created temp table in a SQL cell */

#select * from `2020_Full_Cities_Dataset_1_-1_csv`

# %%
# With this registered as a temp view, it will only be available to this particular notebook. If you'd like other users to be able to query this table, you can also create a table from the DataFrame.
# Once saved, this table will persist across cluster restarts as well as allow various users across different notebooks to query this data.
# To do so, choose your table name and uncomment the bottom line.

#permanent_2020_cities = "2020_full_cities_dataset_1__1_csv"
#df.write.format("parquet").saveAsTable(permanent_2020_cities)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AnalysisException</span>                         Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1218923388978674&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span>
# <span class="ansi-green-intense-fg ansi-bold">      5</span> permanent_2020_cities <span class="ansi-blue-fg">=</span> <span class="ansi-blue-fg">&#34;2020_full_cities_dataset_1__1_csv&#34;</span>
# <span class="ansi-green-fg">----&gt; 6</span><span class="ansi-red-fg"> </span>df<span class="ansi-blue-fg">.</span>write<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#34;parquet&#34;</span><span class="ansi-blue-fg">)</span><span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>permanent_2020_cities<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/readwriter.py</span> in <span class="ansi-cyan-fg">saveAsTable</span><span class="ansi-blue-fg">(self, name, format, mode, partitionBy, **options)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1183</span>         <span class="ansi-green-fg">if</span> format <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">not</span> <span class="ansi-green-fg">None</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">   1184</span>             self<span class="ansi-blue-fg">.</span>format<span class="ansi-blue-fg">(</span>format<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1185</span><span class="ansi-red-fg">         </span>self<span class="ansi-blue-fg">.</span>_jwrite<span class="ansi-blue-fg">.</span>saveAsTable<span class="ansi-blue-fg">(</span>name<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1186</span>
# <span class="ansi-green-intense-fg ansi-bold">   1187</span>     def json(self, path, mode=None, compression=None, dateFormat=None, timestampFormat=None,
#
# <span class="ansi-green-fg">/databricks/spark/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py</span> in <span class="ansi-cyan-fg">__call__</span><span class="ansi-blue-fg">(self, *args)</span>
# <span class="ansi-green-intense-fg ansi-bold">   1302</span>
# <span class="ansi-green-intense-fg ansi-bold">   1303</span>         answer <span class="ansi-blue-fg">=</span> self<span class="ansi-blue-fg">.</span>gateway_client<span class="ansi-blue-fg">.</span>send_command<span class="ansi-blue-fg">(</span>command<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-fg">-&gt; 1304</span><span class="ansi-red-fg">         return_value = get_return_value(
# </span><span class="ansi-green-intense-fg ansi-bold">   1305</span>             answer, self.gateway_client, self.target_id, self.name)
# <span class="ansi-green-intense-fg ansi-bold">   1306</span>
#
# <span class="ansi-green-fg">/databricks/spark/python/pyspark/sql/utils.py</span> in <span class="ansi-cyan-fg">deco</span><span class="ansi-blue-fg">(*a, **kw)</span>
# <span class="ansi-green-intense-fg ansi-bold">    121</span>                 <span class="ansi-red-fg"># Hide where the exception came from that shows a non-Pythonic</span>
# <span class="ansi-green-intense-fg ansi-bold">    122</span>                 <span class="ansi-red-fg"># JVM exception message.</span>
# <span class="ansi-green-fg">--&gt; 123</span><span class="ansi-red-fg">                 </span><span class="ansi-green-fg">raise</span> converted <span class="ansi-green-fg">from</span> <span class="ansi-green-fg">None</span>
# <span class="ansi-green-intense-fg ansi-bold">    124</span>             <span class="ansi-green-fg">else</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-intense-fg ansi-bold">    125</span>                 <span class="ansi-green-fg">raise</span>
#
# <span class="ansi-red-fg">AnalysisException</span>: Attribute name &#34;Year Reported to CDP&#34; contains invalid character(s) among &#34; ,;{}()\n\t=&#34;. Please use alias to rename it.</div>
